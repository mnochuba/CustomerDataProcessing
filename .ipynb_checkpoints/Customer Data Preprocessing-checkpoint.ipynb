# %% [markdown]
# #

# %% [markdown]
# ***
# # <center><font color=#41523A><strong>Programming for Artificial Intelligence and Data Science - 771768<strong><font></center>
# ## <center><font color=#41523A>Final Assessment</font></center>
# ## *__Student ID__: 202324504*
# ## *__Name__: OCHUBA, Murphy Nnamdi*
# ***

# %% [markdown]
# ## __Project Title__: *Customer Data Pre-Processing*

# %% [markdown]
# ### **About the Project:**
# A company has provided us with raw data collected from their customers. In this project, we carry out some pre-processing activities to extract valuable information from the provided data in preparation for further analysis. We also carry out visualisation with `seaborn` to gain more insight into the data.
# ***

# %% [markdown]
# ## **Part One: Data Processing**

# %%
# Import needed libraries for data processing
import csv
import json
import ast as evaluator #python built-in standard library to convert strings to their respective types

# %% [markdown]
# ***
# ### <u>**Task 1 & 2**:</u>
# a. Read in data from the CSV file provided by the customer. <br>
# b. Convert the flat structure to a nested dictionary.
# ***

# %%
# Customer class to create a new customer object for each row of the csv file
# We can also achieve this using a simple function but I have used a class here 
# to demonstrate Object-Oriented Programming (OOP) in python.

class Customer():
    """
    A class used to represent a Customer
    ...

    Attributes
    ----------
    customer_data : dict
        A dictionary containing key-value pairs of the customer data.
        
    Methods
    -------
    evaluate_expr(self, expr)
        Checks a given value expressed as a string and converts it to its appropriate type.
    
    sort_customer_keys(self, my_dictionary)
        Sorts the keys of the customer dictionary in a predefined order.
    """
    
    def __init__(self, csv_dict_reader_row): # Class constructor takes one row from the csv and transforms it to a customer dictionary
        """
        Parameters
        ----------
        csv_dict_reader_row : csv.DictReader
            An iterable csv.DictReader object to be transformed into a dictionary
        """
        
        #Initialise address, vehicle, and credit card dictionaries
        address = {}
        vehicle = {}
        credit_card = {}
        #Initialise customer dictionary
        customer = {}
        for col_key, col_value in csv_dict_reader_row.items():
            if 'Address' in col_key: #check if the column is an address field
                address[col_key.replace('Address ', '')] = self.evaluate_expr(col_value) # take off 'Address' from column header and add value to the address dictionary
            elif 'Vehicle' in col_key:
                vehicle[col_key.replace('Vehicle ', '')] = self.evaluate_expr(col_value) # take off 'Vehicle' from column header and add value to the address dictionary
            elif 'Credit' in col_key:
                credit_card[col_key.replace('Credit Card ', '')] = self.evaluate_expr(col_value) # take off 'Credit Card' from column header and add value to the address dictionary
            else:
                customer[col_key] = self.evaluate_expr(col_value) #Add value directly to customer dictionary if it doesn't need nesting
        #Add address, vehicle, and credit card dictionaries to customer dictionary
        customer['Address'] = address
        customer['Vehicle'] = vehicle
        customer['Credit Card'] = credit_card
        # sorted_customer = self.sort_customer_keys(customer)
        self.customer_data = customer
            
    def evaluate_expr(self, expr): 
        """
        This function takes a literal string and casts it to its appropriate type.
    
        Parameters:
        - expr (string): The literal string that needs casting.
    
        Returns:
        int, float, bool, or string: The converted value.
        """
        try:
            result = evaluator.literal_eval(expr)
        except:
            return expr
        return result


    def sort_customer_keys(self, my_dictionary):
        """
        This function sorts a dictionary keys in a given order.
    
        Parameters:
        - my_dictionary (dictionary): The customer dictionary whose keys are to be sorted.
    
        Returns:
        dict: The sorted dictionary.
        """
        #Sort the keys of the dictionary in a given order}
        # Define the desired order of keys
        key_order = ['First Name', 'Last Name','Sex', 'Age (Years)', 'Dependants', 'Marital Status', 'Employer Company', 'Retired',
                     'Yearly Salary (GBP)', 'Yearly Pension (GBP)', 'Distance Commuted to Work (Km)',  'Bank IBAN', 'Address', 'Vehicle', 'Credit Card']

        # Sort customer keys using the defined order
        sorted_keys = sorted(my_dictionary.keys(), key=lambda x: key_order.index(x))
        
        # Create a new customer dictionary with sorted keys
        sorted_cust = {key: my_dictionary[key] for key in sorted_keys}
        return sorted_cust

# %%
# Function to take in a customer DictReader object from a csv file
# and convert the flat structure to a list of nested dictionaries using the Customer class

def restructure_customer_data(csv_dict_reader):
    """
    This function takes a csv DictReader object and converts the flat structure to 
    a list of nested dictionaries using the Customer class.

    Parameters:
    - csv_dict_reader (DictReader object): An iterator that produces a dictionary for each row of a csv file.

    Returns:
    list of Customer: A list of customer dictionaries
    """
    ochubas_customers = []
    for row in csv_dict_reader:
            ochubas_customer = Customer(row)
            ochubas_customers.append(ochubas_customer.customer_data)
    return ochubas_customers

# %%
# Actual execution for task 1 & 2 using the function and class created in the cells above
# Using a context manager, read in csv file and create the customer list 
file_path = 'acw_user_data.csv' # Specify file path to read from
ochubas_customers = [] #Initilise list to hold our customers
try:
    with open(file_path, 'r') as customer_csv_file:
        customer_csv_reader = csv.DictReader(customer_csv_file) # Read in the data from the csv file using DictReader
        ochubas_customers = restructure_customer_data(customer_csv_reader)    
except FileNotFoundError as file_error:
    print(f'An error occured: {file_error}')
except:
    print(f'Error occurred while reading from {file_path}')
else: 
    # Print the customer list to inspect the output
    for ochubas_customer in ochubas_customers:
        print(ochubas_customer)
# Out:
# {'Age (Years)': 89, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 3, 'First Name': 'Kieran', 'Bank IBAN': 'GB62PQKB71416034141571', 'Last Name': 'Wilson', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 7257, 'Retired': True, 'Yearly Salary (GBP)': 72838, 'Sex': 'Male', 'Address': {'Street': '70 Lydia isle', 'City': 'Lake Conor', 'Postcode': 'S71 7XZ'}, 'Vehicle': {'Make': 'Hyundai', 'Model': 'Bonneville', 'Year': 2009, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '08/18', 'Expiry Date': '11/27', 'Number': 676373692463, 'CVV': 875}}
# {'Age (Years)': 46, 'Distance Commuted to Work (Km)': 13.72, 'Employer Company': 'Begum-Williams', 'Dependants': 1, 'First Name': 'Jonathan', 'Bank IBAN': 'GB37UMCO54540228728019', 'Last Name': 'Thomas', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 54016, 'Sex': 'Male', 'Address': {'Street': '00 Wheeler wells', 'City': 'Chapmanton', 'Postcode': 'L2 7BT'}, 'Vehicle': {'Make': 'Nissan', 'Model': 'ATS', 'Year': 1996, 'Type': 'Coupe'}, 'Credit Card': {'Start Date': '08/12', 'Expiry Date': '11/26', 'Number': 4529436854129855, 'CVV': 583}}
# {'Age (Years)': 22, 'Distance Commuted to Work (Km)': 16.02, 'Employer Company': 'Hill-Wright', 'Dependants': 1, 'First Name': 'Antony', 'Bank IBAN': 'GB40CVUE84011545859591', 'Last Name': 'Jones', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 68049, 'Sex': 'Male', 'Address': {'Street': 'Studio 33K Joel walk', 'City': 'Randallborough', 'Postcode': 'ME3N 1GH'}, 'Vehicle': {'Make': 'GMC', 'Model': 'Achieva', 'Year': 2015, 'Type': 'Convertible, Coupe'}, 'Credit Card': {'Start Date': '11/19', 'Expiry Date': '07/27', 'Number': 4091726363083888495, 'CVV': 422}}
# {'Age (Years)': 56, 'Distance Commuted to Work (Km)': 19.35, 'Employer Company': 'Green LLC', 'Dependants': 2, 'First Name': 'Henry', 'Bank IBAN': 'GB40YPKK71613332239280', 'Last Name': 'Shaw', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 91337, 'Sex': 'Male', 'Address': {'Street': 'Studio 46S Bethany lights', 'City': 'East Reece', 'Postcode': 'E10 9RJ'}, 'Vehicle': {'Make': 'Scion', 'Model': 'F150 SuperCrew Cab', 'Year': 1994, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '10/17', 'Expiry Date': '04/18', 'Number': 4671332769487632633, 'CVV': 669}}
# {'Age (Years)': 57, 'Distance Commuted to Work (Km)': 5.94, 'Employer Company': 'Hill, Evans and Harrison', 'Dependants': 2, 'First Name': 'Jodie', 'Bank IBAN': 'GB95WAYW31715898077181', 'Last Name': "O'Brien", 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 18446, 'Sex': 'Female', 'Address': {'Street': 'Flat 3 Christine views', 'City': 'Fletcherstad', 'Postcode': 'WS2 9SN'}, 'Vehicle': {'Make': 'Buick', 'Model': 'Outback', 'Year': 2020, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '04/19', 'Expiry Date': '11/27', 'Number': 2245094149128526, 'CVV': 659}}
# {'Age (Years)': 23, 'Distance Commuted to Work (Km)': 10.73, 'Employer Company': 'Gill and Sons', 'Dependants': 3, 'First Name': 'Ryan', 'Bank IBAN': 'GB29SSDY05529526374313', 'Last Name': 'Clarke', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 38100, 'Sex': 'Male', 'Address': {'Street': 'Studio 43M Emily rapid', 'City': 'West Derekborough', 'Postcode': 'W1J 0DL'}, 'Vehicle': {'Make': 'Lexus', 'Model': 'Paceman', 'Year': 2004, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '03/15', 'Expiry Date': '05/15', 'Number': 4485214746578045493, 'CVV': 123}}
# {'Age (Years)': 43, 'Distance Commuted to Work (Km)': 20.05, 'Employer Company': 'Clark Group', 'Dependants': 3, 'First Name': 'Julian', 'Bank IBAN': 'GB92PWOB18937027850061', 'Last Name': 'Potter', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 96645, 'Sex': 'Male', 'Address': {'Street': '24 Heather locks', 'City': 'New Mathew', 'Postcode': 'WD10 1LX'}, 'Vehicle': {'Make': 'Lexus', 'Model': 'S-Series', 'Year': 1998, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '07/12', 'Expiry Date': '03/29', 'Number': 36970652008212, 'CVV': 622}}
# {'Age (Years)': 67, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 1, 'First Name': 'Clive', 'Bank IBAN': 'GB04VSAZ69128049616822', 'Last Name': 'Evans', 'Marital Status': 'single', 'Yearly Pension (GBP)': 28075, 'Retired': True, 'Yearly Salary (GBP)': 27964, 'Sex': 'Male', 'Address': {'Street': '81 Goodwin dam', 'City': 'Griffinstad', 'Postcode': 'G3 7ZX'}, 'Vehicle': {'Make': 'Volvo', 'Model': 'Express 3500 Passenger', 'Year': 2013, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '07/15', 'Expiry Date': '04/27', 'Number': 213199489183130, 'CVV': 389}}
# {'Age (Years)': 33, 'Distance Commuted to Work (Km)': 15.29, 'Employer Company': 'Richardson and Sons', 'Dependants': 2, 'First Name': 'Joan', 'Bank IBAN': 'GB80GFKU97154647098789', 'Last Name': 'Stanley', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 63433, 'Sex': 'Female', 'Address': {'Street': '798 Yates crescent', 'City': 'Port Lisa', 'Postcode': 'LS0M 7UU'}, 'Vehicle': {'Make': 'Volkswagen', 'Model': 'Town & Country', 'Year': 2010, 'Type': 'Sedan, Coupe, Hatchback'}, 'Credit Card': {'Start Date': '05/13', 'Expiry Date': '08/20', 'Number': 30167634782545, 'CVV': 849}}
# {'Age (Years)': 87, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 2, 'First Name': 'Malcolm', 'Bank IBAN': 'GB74TXVQ82130006568515', 'Last Name': 'Hamilton', 'Marital Status': 'single', 'Yearly Pension (GBP)': 29587, 'Retired': True, 'Yearly Salary (GBP)': 66157, 'Sex': 'Male', 'Address': {'Street': 'Studio 77c Gail tunnel', 'City': 'Garyberg', 'Postcode': 'S7W 4DW'}, 'Vehicle': {'Make': 'Dodge', 'Model': 'Impreza', 'Year': 2015, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '10/13', 'Expiry Date': '10/13', 'Number': 213198388220332, 'CVV': 766}}
# {'Age (Years)': 64, 'Distance Commuted to Work (Km)': 11.11, 'Employer Company': 'Gray-James', 'Dependants': 3, 'First Name': 'Kimberley', 'Bank IBAN': 'GB95JQAU66555098753975', 'Last Name': 'Turner', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 39983, 'Sex': 'Female', 'Address': {'Street': '2 Robert squares', 'City': 'North Martyn', 'Postcode': 'LN2 4JH'}, 'Vehicle': {'Make': 'Volvo', 'Model': 'Tundra Double Cab', 'Year': 2011, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '05/19', 'Expiry Date': '03/29', 'Number': 4707491977031086, 'CVV': 843}}
# {'Age (Years)': 68, 'Distance Commuted to Work (Km)': 7.5, 'Employer Company': 'Mitchell-Brown', 'Dependants': 2, 'First Name': 'Stuart', 'Bank IBAN': 'GB52JKQX17539370637650', 'Last Name': 'Page', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 24062, 'Sex': 'Male', 'Address': {'Street': '6 Frances flats', 'City': 'Lake Amberchester', 'Postcode': 'NE5E 5AD'}, 'Vehicle': {'Make': 'Volkswagen', 'Model': 'Stratus', 'Year': 2012, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '06/18', 'Expiry Date': '12/22', 'Number': 4028404782978, 'CVV': 404}}
# {'Age (Years)': 45, 'Distance Commuted to Work (Km)': 20.21, 'Employer Company': 'Bailey, Gibson and Wallace', 'Dependants': 3, 'First Name': 'Hollie', 'Bank IBAN': 'GB32JFUZ85486983593277', 'Last Name': 'Gray', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 97948, 'Sex': 'Female', 'Address': {'Street': 'Flat 29 Liam greens', 'City': 'West Liamview', 'Postcode': 'S78 9WZ'}, 'Vehicle': {'Make': 'Ford', 'Model': '1500 Regular Cab', 'Year': 2008, 'Type': 'Convertible'}, 'Credit Card': {'Start Date': '03/19', 'Expiry Date': '02/23', 'Number': 374755790990128, 'CVV': 237}}
# {'Age (Years)': 56, 'Distance Commuted to Work (Km)': 9.48, 'Employer Company': 'Jones Inc', 'Dependants': 3, 'First Name': 'Lawrence', 'Bank IBAN': 'GB80OOIU80240902240471', 'Last Name': 'Smith', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 32281, 'Sex': 'Male', 'Address': {'Street': 'Studio 75 Matthew tunnel', 'City': 'Patelville', 'Postcode': 'L85 4LT'}, 'Vehicle': {'Make': 'Lincoln', 'Model': 'Sierra 2500 HD Crew Cab', 'Year': 2016, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '04/17', 'Expiry Date': '12/20', 'Number': 3555499142173001, 'CVV': '069'}}
# {'Age (Years)': 78, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 4, 'First Name': 'Jade', 'Bank IBAN': 'GB76WOAN35375600936407', 'Last Name': 'John', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 24712, 'Retired': True, 'Yearly Salary (GBP)': 59891, 'Sex': 'Female', 'Address': {'Street': '8 Bray row', 'City': 'Daviestown', 'Postcode': 'S2H 5RE'}, 'Vehicle': {'Make': 'Nissan', 'Model': 'LC', 'Year': 2012, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '10/12', 'Expiry Date': '12/19', 'Number': 4548406264381245, 'CVV': '022'}}
# {'Age (Years)': 55, 'Distance Commuted to Work (Km)': 17.53, 'Employer Company': 'Butler PLC', 'Dependants': 2, 'First Name': 'Ronald', 'Bank IBAN': 'GB63SWMR56023428926868', 'Last Name': 'Pearce', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 78214, 'Sex': 'Male', 'Address': {'Street': '8 Lesley estates', 'City': 'South Albertmouth', 'Postcode': 'L1D 2GY'}, 'Vehicle': {'Make': 'Acura', 'Model': 'S10 Regular Cab', 'Year': 1999, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '06/14', 'Expiry Date': '04/29', 'Number': 4039986704298, 'CVV': 885}}
# {'Age (Years)': 40, 'Distance Commuted to Work (Km)': 18.76, 'Employer Company': 'White PLC', 'Dependants': 3, 'First Name': 'Josephine', 'Bank IBAN': 'GB95JPHC00666850049083', 'Last Name': 'Saunders', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 86961, 'Sex': 'Female', 'Address': {'Street': '6 Karl path', 'City': 'Lake Kateborough', 'Postcode': 'L2 1YW'}, 'Vehicle': {'Make': 'Hyundai', 'Model': 'Colorado Extended Cab', 'Year': 2017, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '07/14', 'Expiry Date': '02/17', 'Number': 3581971298353411, 'CVV': 388}}
# {'Age (Years)': 28, 'Distance Commuted to Work (Km)': 6.65, 'Employer Company': 'McCarthy and Sons', 'Dependants': 2, 'First Name': 'Tina', 'Bank IBAN': 'GB02YMXX98886109551024', 'Last Name': 'Thornton', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 20918, 'Sex': 'Female', 'Address': {'Street': 'Studio 9 Joan tunnel', 'City': 'Birdview', 'Postcode': 'LS3 9ZL'}, 'Vehicle': {'Make': 'Mercedes-Benz', 'Model': 'RX', 'Year': 1992, 'Type': 'Hatchback, Convertible'}, 'Credit Card': {'Start Date': '03/14', 'Expiry Date': '06/23', 'Number': 6011733962385373, 'CVV': 588}}
# {'Age (Years)': 64, 'Distance Commuted to Work (Km)': 11.2, 'Employer Company': 'Dickinson LLC', 'Dependants': 3, 'First Name': 'Lauren', 'Bank IBAN': 'GB13NXGK90881253380683', 'Last Name': 'Smith', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 40432, 'Sex': 'Female', 'Address': {'Street': 'Studio 24F Cartwright mission', 'City': 'Lake Cheryl', 'Postcode': 'EX5 7QJ'}, 'Vehicle': {'Make': 'Nissan', 'Model': 'Ram 3500 Quad Cab', 'Year': 2019, 'Type': 'Wagon, Sedan'}, 'Credit Card': {'Start Date': '09/13', 'Expiry Date': '04/16', 'Number': 4523397892032574, 'CVV': 592}}
# {'Age (Years)': 61, 'Distance Commuted to Work (Km)': 15.12, 'Employer Company': 'Pugh-Ahmed', 'Dependants': 2, 'First Name': 'Tracy', 'Bank IBAN': 'GB46TBUI88094503861317', 'Last Name': 'White', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 62377, 'Sex': 'Female', 'Address': {'Street': '409 Julie cliff', 'City': 'North Benjamin', 'Postcode': 'SK1 8EA'}, 'Vehicle': {'Make': 'Chevrolet', 'Model': 'Navigator', 'Year': 2008, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '12/11', 'Expiry Date': '08/19', 'Number': 4346081794995850891, 'CVV': 981}}
# {'Age (Years)': 61, 'Distance Commuted to Work (Km)': 18.23, 'Employer Company': 'Wall Inc', 'Dependants': 2, 'First Name': 'Lynne', 'Bank IBAN': 'GB95OJRW46308657171586', 'Last Name': 'Smith', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 83114, 'Sex': 'Female', 'Address': {'Street': 'Studio 98v Watson manors', 'City': 'Parkershire', 'Postcode': 'E58 7QE'}, 'Vehicle': {'Make': 'Ford', 'Model': 'Sierra 2500 HD Regular Cab', 'Year': 2009, 'Type': 'Wagon'}, 'Credit Card': {'Start Date': '07/18', 'Expiry Date': '06/20', 'Number': 4202590910095, 'CVV': 215}}
# {'Age (Years)': 40, 'Distance Commuted to Work (Km)': 11.98, 'Employer Company': 'Frost-Howard', 'Dependants': '', 'First Name': 'Sian', 'Bank IBAN': 'GB24RDII19341179851384', 'Last Name': 'Marshall', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 44434, 'Sex': 'Female', 'Address': {'Street': '9 Hargreaves loaf', 'City': 'New Keith', 'Postcode': 'OX85 1NN'}, 'Vehicle': {'Make': 'MAZDA', 'Model': 'Tundra Regular Cab', 'Year': 2001, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '09/18', 'Expiry Date': '02/23', 'Number': 3577676608962779, 'CVV': 426}}
# {'Age (Years)': 75, 'Distance Commuted to Work (Km)': 17.76, 'Employer Company': 'Taylor-Price', 'Dependants': 1, 'First Name': 'Lindsey', 'Bank IBAN': 'GB13LRBV70338974739597', 'Last Name': 'Williams', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 79823, 'Sex': 'Female', 'Address': {'Street': 'Studio 5 Morgan shore', 'City': 'Murrayshire', 'Postcode': 'N2B 6BQ'}, 'Vehicle': {'Make': 'Toyota', 'Model': 'Silverado 3500 HD Crew Cab', 'Year': 2008, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '12/17', 'Expiry Date': '07/25', 'Number': 3595195711581002, 'CVV': 779}}
# {'Age (Years)': 30, 'Distance Commuted to Work (Km)': 17.22, 'Employer Company': 'Chapman-Roberts', 'Dependants': 2, 'First Name': 'Billy', 'Bank IBAN': 'GB20SYOG64532798985587', 'Last Name': 'Turner', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 76038, 'Sex': 'Male', 'Address': {'Street': 'Flat 7 Nicholas extensions', 'City': 'Claireside', 'Postcode': 'G1 8ND'}, 'Vehicle': {'Make': 'Mitsubishi', 'Model': 'Optima Hybrid', 'Year': 2002, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '07/12', 'Expiry Date': '01/24', 'Number': 4424772815182245, 'CVV': 844}}
# {'Age (Years)': 52, 'Distance Commuted to Work (Km)': 17.57, 'Employer Company': 'Hall, Chambers and Hussain', 'Dependants': 2, 'First Name': 'Elliot', 'Bank IBAN': 'GB33EXFR41119491231301', 'Last Name': 'Iqbal', 'Marital Status': 'widowed', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 78499, 'Sex': 'Male', 'Address': {'Street': 'Studio 3 Duncan spurs', 'City': 'Briggsside', 'Postcode': 'E0T 1XP'}, 'Vehicle': {'Make': 'Chrysler', 'Model': 'Camry', 'Year': 2000, 'Type': 'Coupe'}, 'Credit Card': {'Start Date': '09/20', 'Expiry Date': '05/21', 'Number': 341069667039658, 'CVV': 653}}
# {'Age (Years)': 58, 'Distance Commuted to Work (Km)': 10.68, 'Employer Company': 'Hall-Bishop', 'Dependants': 1, 'First Name': 'Jessica', 'Bank IBAN': 'GB34JTYZ40582231795531', 'Last Name': 'Carr', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 37866, 'Sex': 'Female', 'Address': {'Street': '4 Mitchell ranch', 'City': 'Lake Josephinechester', 'Postcode': 'N5S 7YJ'}, 'Vehicle': {'Make': 'Dodge', 'Model': 'Talon', 'Year': 2014, 'Type': 'Coupe, Convertible'}, 'Credit Card': {'Start Date': '09/20', 'Expiry Date': '02/28', 'Number': 3539835635041729, 'CVV': 555}}
# {'Age (Years)': 32, 'Distance Commuted to Work (Km)': 16.42, 'Employer Company': 'Rogers, Richards and Thomas', 'Dependants': 2, 'First Name': 'Caroline', 'Bank IBAN': 'GB02HCXE02205190652485', 'Last Name': 'Clarke', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 70655, 'Sex': 'Female', 'Address': {'Street': '235 Smith path', 'City': 'Singhmouth', 'Postcode': 'WN71 7XD'}, 'Vehicle': {'Make': 'Hyundai', 'Model': 'Monte Carlo', 'Year': 2011, 'Type': 'Sedan, Wagon'}, 'Credit Card': {'Start Date': '05/15', 'Expiry Date': '04/24', 'Number': 6011152289949748, 'CVV': 190}}
# {'Age (Years)': 36, 'Distance Commuted to Work (Km)': 17.64, 'Employer Company': 'Henry, Gibson and French', 'Dependants': 3, 'First Name': 'Jack', 'Bank IBAN': 'GB64SWHN93102765498771', 'Last Name': 'Porter', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 78955, 'Sex': 'Male', 'Address': {'Street': 'Studio 76l Carr mill', 'City': 'South Francesborough', 'Postcode': 'W7 1DR'}, 'Vehicle': {'Make': 'Kia', 'Model': 'X3', 'Year': 2018, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '09/12', 'Expiry Date': '04/17', 'Number': 581933729880, 'CVV': 7258}}
# {'Age (Years)': 18, 'Distance Commuted to Work (Km)': 19.49, 'Employer Company': 'Barnett, Jones and Jones', 'Dependants': 2, 'First Name': 'Gavin', 'Bank IBAN': 'GB15JSIN49600511879663', 'Last Name': 'Chapman', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 92384, 'Sex': 'Male', 'Address': {'Street': '385 Ward rue', 'City': 'Abigailport', 'Postcode': 'AL0 4BW'}, 'Vehicle': {'Make': 'Nissan', 'Model': 'Canyon Extended Cab', 'Year': 2014, 'Type': 'Coupe'}, 'Credit Card': {'Start Date': '02/13', 'Expiry Date': '03/14', 'Number': 2718161701884669, 'CVV': 5547}}
# {'Age (Years)': 80, 'Distance Commuted to Work (Km)': 19.67, 'Employer Company': 'Clark, Evans and Lloyd', 'Dependants': 1, 'First Name': 'Dennis', 'Bank IBAN': 'GB67BTBB81025265475465', 'Last Name': 'Johnson', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 93744, 'Sex': 'Male', 'Address': {'Street': 'Flat 59T Barry loop', 'City': 'Lindaton', 'Postcode': 'B60 3LJ'}, 'Vehicle': {'Make': 'Nissan', 'Model': 'Spirit', 'Year': 2006, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '05/18', 'Expiry Date': '01/27', 'Number': 4880276853281, 'CVV': '020'}}
# {'Age (Years)': 55, 'Distance Commuted to Work (Km)': 14.53, 'Employer Company': 'May, Bennett and Wood', 'Dependants': 2, 'First Name': 'Rhys', 'Bank IBAN': 'GB96MSSE31514251878599', 'Last Name': 'George', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 58770, 'Sex': 'Male', 'Address': {'Street': '4 Patel curve', 'City': 'Robertstad', 'Postcode': 'DT33 1UL'}, 'Vehicle': {'Make': 'Aston Martin', 'Model': 'Sierra 1500 Crew Cab', 'Year': 1993, 'Type': 'Hatchback'}, 'Credit Card': {'Start Date': '07/12', 'Expiry Date': '03/24', 'Number': 3545097391550953, 'CVV': 106}}
# {'Age (Years)': 65, 'Distance Commuted to Work (Km)': 7.21, 'Employer Company': 'Warren, Burton and Spencer', 'Dependants': 1, 'First Name': 'Denis', 'Bank IBAN': 'GB61PVEV06020291833305', 'Last Name': 'Brown', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 22959, 'Sex': 'Male', 'Address': {'Street': '949 Kirsty walk', 'City': 'Rickymouth', 'Postcode': 'N77 4DX'}, 'Vehicle': {'Make': 'Ford', 'Model': 'Yukon XL 1500', 'Year': 2007, 'Type': 'Wagon, Sedan, Coupe'}, 'Credit Card': {'Start Date': '08/12', 'Expiry Date': '04/17', 'Number': 3532744524925124, 'CVV': 570}}
# {'Age (Years)': 82, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 5, 'First Name': 'Helen', 'Bank IBAN': 'GB42TNFG09550061109890', 'Last Name': 'Kaur', 'Marital Status': 'single', 'Yearly Pension (GBP)': 28731, 'Retired': True, 'Yearly Salary (GBP)': 80297, 'Sex': 'Female', 'Address': {'Street': 'Flat 47 Godfrey road', 'City': 'West Brianfurt', 'Postcode': 'S6G 3HB'}, 'Vehicle': {'Make': 'Acura', 'Model': 'G', 'Year': 1998, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '01/18', 'Expiry Date': '07/28', 'Number': 5543467566659730, 'CVV': 465}}
# {'Age (Years)': 39, 'Distance Commuted to Work (Km)': 18.81, 'Employer Company': 'Kay, Chapman and Wilson', 'Dependants': 2, 'First Name': 'Jeffrey', 'Bank IBAN': 'GB34LHKJ06609001114424', 'Last Name': 'Humphreys', 'Marital Status': 'divorced', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 87308, 'Sex': 'Male', 'Address': {'Street': '004 Julian estates', 'City': 'Colinhaven', 'Postcode': 'KT54 9TR'}, 'Vehicle': {'Make': 'Saab', 'Model': 'Transit Connect Cargo', 'Year': 2005, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '01/16', 'Expiry Date': '08/25', 'Number': 4104552697048756, 'CVV': 615}}
# {'Age (Years)': 83, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 2, 'First Name': 'Adam', 'Bank IBAN': 'GB76KUNW91632428208056', 'Last Name': 'Wright', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 30115, 'Retired': True, 'Yearly Salary (GBP)': 70109, 'Sex': 'Male', 'Address': {'Street': 'Flat 32 Sharp prairie', 'City': 'Marcusstad', 'Postcode': 'AB57 0ZN'}, 'Vehicle': {'Make': 'GMC', 'Model': 'Frontier Crew Cab', 'Year': 1998, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '02/12', 'Expiry Date': '03/24', 'Number': 2426144247746702, 'CVV': 453}}
# {'Age (Years)': 65, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 2, 'First Name': 'Danielle', 'Bank IBAN': 'GB77BKAA88748168755170', 'Last Name': 'Robertson', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 8022, 'Retired': True, 'Yearly Salary (GBP)': 57953, 'Sex': 'Female', 'Address': {'Street': '8 Michael cliff', 'City': 'Joanchester', 'Postcode': 'B8E 0XR'}, 'Vehicle': {'Make': 'Jaguar', 'Model': 'Odyssey', 'Year': 1997, 'Type': 'Hatchback'}, 'Credit Card': {'Start Date': '05/14', 'Expiry Date': '12/27', 'Number': 30253997599666, 'CVV': 479}}
# {'Age (Years)': 42, 'Distance Commuted to Work (Km)': 12.44, 'Employer Company': 'Stevenson Group', 'Dependants': 2, 'First Name': 'Joyce', 'Bank IBAN': 'GB09RXOP90874575465239', 'Last Name': 'Brown', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 46864, 'Sex': 'Female', 'Address': {'Street': 'Studio 63 Rachel underpass', 'City': 'Gallaghermouth', 'Postcode': 'G99 3GH'}, 'Vehicle': {'Make': 'Mercedes-Benz', 'Model': 'Veloster', 'Year': 2011, 'Type': 'Convertible'}, 'Credit Card': {'Start Date': '07/13', 'Expiry Date': '08/13', 'Number': 4613132283561, 'CVV': 926}}
# {'Age (Years)': 91, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 2, 'First Name': 'Vanessa', 'Bank IBAN': 'GB75HZCQ22453289425740', 'Last Name': 'Kay', 'Marital Status': 'single', 'Yearly Pension (GBP)': 30866, 'Retired': True, 'Yearly Salary (GBP)': 81220, 'Sex': 'Female', 'Address': {'Street': '7 Williams forks', 'City': 'Cookside', 'Postcode': 'N6 2YZ'}, 'Vehicle': {'Make': 'Chevrolet', 'Model': 'Viper', 'Year': 2015, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '06/19', 'Expiry Date': '11/21', 'Number': 4232054778076, 'CVV': 752}}
# {'Age (Years)': 35, 'Distance Commuted to Work (Km)': 15.36, 'Employer Company': 'Wright and Sons', 'Dependants': 4, 'First Name': 'Dawn', 'Bank IBAN': 'GB86CXKN23940068226539', 'Last Name': 'Young', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 63857, 'Sex': 'Female', 'Address': {'Street': '75 Gordon courts', 'City': 'Lorraineberg', 'Postcode': 'L56 2JA'}, 'Vehicle': {'Make': 'Chevrolet', 'Model': 'S2000', 'Year': 2002, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '10/19', 'Expiry Date': '07/21', 'Number': 6011199971776715, 'CVV': 660}}
# {'Age (Years)': 54, 'Distance Commuted to Work (Km)': 9.85, 'Employer Company': 'Thomson, Kirby and Barker', 'Dependants': 1, 'First Name': 'Darren', 'Bank IBAN': 'GB12URYF32648832649281', 'Last Name': 'Nicholls', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 33987, 'Sex': 'Male', 'Address': {'Street': 'Studio 09F Allen road', 'City': 'Port Rachel', 'Postcode': 'TS9 1TL'}, 'Vehicle': {'Make': 'Volkswagen', 'Model': 300, 'Year': 2015, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '05/19', 'Expiry Date': '08/23', 'Number': 3583769124026773, 'CVV': 113}}
# {'Age (Years)': 20, 'Distance Commuted to Work (Km)': 7.65, 'Employer Company': 'Smith-Smith', 'Dependants': 2, 'First Name': 'Lauren', 'Bank IBAN': 'GB41AMAJ35865980015154', 'Last Name': 'Martin', 'Marital Status': 'widowed', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 24652, 'Sex': 'Female', 'Address': {'Street': 'Studio 7 Jemma cliff', 'City': 'Turnerbury', 'Postcode': 'B98 1HT'}, 'Vehicle': {'Make': 'GMC', 'Model': 'Phaeton', 'Year': 2008, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '04/12', 'Expiry Date': '01/24', 'Number': 4930019983947687, 'CVV': 373}}
# {'Age (Years)': 51, 'Distance Commuted to Work (Km)': 6.45, 'Employer Company': 'Clarke Inc', 'Dependants': 2, 'First Name': 'Melanie', 'Bank IBAN': 'GB14FFMB81152248185033', 'Last Name': "O'Brien", 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 20206, 'Sex': 'Female', 'Address': {'Street': 'Flat 08d Ward squares', 'City': 'Phillipside', 'Postcode': 'BB3A 9PE'}, 'Vehicle': {'Make': 'Pontiac', 'Model': '2500 Regular Cab', 'Year': 1997, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '01/12', 'Expiry Date': '09/23', 'Number': 213157599544104, 'CVV': 542}}
# {'Age (Years)': 42, 'Distance Commuted to Work (Km)': 20.08, 'Employer Company': 'Smith PLC', 'Dependants': 2, 'First Name': 'Vanessa', 'Bank IBAN': 'GB50MQKE98379126728837', 'Last Name': 'Hussain', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 96882, 'Sex': 'Female', 'Address': {'Street': '28 Oliver fort', 'City': 'Melissaport', 'Postcode': 'DY95 0UG'}, 'Vehicle': {'Make': 'Lexus', 'Model': 'TrailBlazer', 'Year': 2001, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '12/13', 'Expiry Date': '11/14', 'Number': 4028668051434623, 'CVV': 326}}
# {'Age (Years)': 43, 'Distance Commuted to Work (Km)': 17.96, 'Employer Company': 'Sutton LLC', 'Dependants': 2, 'First Name': 'Chelsea', 'Bank IBAN': 'GB23IKFU36409120028603', 'Last Name': 'Thorpe', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 81215, 'Sex': 'Female', 'Address': {'Street': 'Flat 39 Shaun dam', 'City': 'Martinbury', 'Postcode': 'N9W 3EN'}, 'Vehicle': {'Make': 'Nissan', 'Model': 'Tundra Regular Cab', 'Year': 2013, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '06/16', 'Expiry Date': '01/17', 'Number': 2240925048327112, 'CVV': 751}}
# {'Age (Years)': 38, 'Distance Commuted to Work (Km)': 6.35, 'Employer Company': 'Dickinson, Nolan and Smith', 'Dependants': 2, 'First Name': 'Sarah', 'Bank IBAN': 'GB72SOVW84817129799960', 'Last Name': 'Robinson', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 19863, 'Sex': 'Female', 'Address': {'Street': 'Studio 77T Emily path', 'City': 'West Connor', 'Postcode': 'NW7B 5ZR'}, 'Vehicle': {'Make': 'INFINITI', 'Model': 'Sportvan G20', 'Year': 2020, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '09/18', 'Expiry Date': '02/26', 'Number': 4420932692384285170, 'CVV': 800}}
# {'Age (Years)': 59, 'Distance Commuted to Work (Km)': 15.52, 'Employer Company': 'Blake-Johnson', 'Dependants': 1, 'First Name': 'Zoe', 'Bank IBAN': 'GB73OAWO74482506912387', 'Last Name': 'Williams', 'Marital Status': 'widowed', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 64885, 'Sex': 'Female', 'Address': {'Street': 'Flat 66f Anderson fords', 'City': 'Aaronburgh', 'Postcode': 'E33 3NW'}, 'Vehicle': {'Make': 'Cadillac', 'Model': 'Tacoma Double Cab', 'Year': 2016, 'Type': 'Coupe, Sedan'}, 'Credit Card': {'Start Date': '04/20', 'Expiry Date': '02/26', 'Number': 4857329278730664690, 'CVV': 854}}
# {'Age (Years)': 84, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 1, 'First Name': 'Sheila', 'Bank IBAN': 'GB28KWDH09406690563679', 'Last Name': 'Woodward', 'Marital Status': 'single', 'Yearly Pension (GBP)': 24080, 'Retired': True, 'Yearly Salary (GBP)': 59223, 'Sex': 'Female', 'Address': {'Street': '1 Holt knoll', 'City': 'Ianview', 'Postcode': 'L93 2QY'}, 'Vehicle': {'Make': 'Audi', 'Model': 'Celica', 'Year': 2016, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '06/12', 'Expiry Date': '09/17', 'Number': 2278690061462569, 'CVV': 243}}
# {'Age (Years)': 72, 'Distance Commuted to Work (Km)': 9.28, 'Employer Company': 'Archer-Dean', 'Dependants': 2, 'First Name': 'Dorothy', 'Bank IBAN': 'GB53SWXB45203854278672', 'Last Name': 'Leonard', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 31412, 'Sex': 'Female', 'Address': {'Street': 'Studio 30X Clive hills', 'City': 'East Katemouth', 'Postcode': 'SN5V 1JD'}, 'Vehicle': {'Make': 'Dodge', 'Model': 'B-Series Regular Cab', 'Year': 2017, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '05/15', 'Expiry Date': '10/18', 'Number': 38689453799039, 'CVV': 510}}
# {'Age (Years)': 50, 'Distance Commuted to Work (Km)': 5.81, 'Employer Company': 'Williams-Jones', 'Dependants': 2, 'First Name': 'Ashley', 'Bank IBAN': 'GB22OTJE53991614349608', 'Last Name': 'Sullivan', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 18005, 'Sex': 'Male', 'Address': {'Street': '34 Amanda trace', 'City': 'North Juliamouth', 'Postcode': 'HU28 3AR'}, 'Vehicle': {'Make': 'Mercedes-Benz', 'Model': 'Sprinter 2500 Crew', 'Year': 2014, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '06/12', 'Expiry Date': '07/17', 'Number': 379250853696551, 'CVV': 586}}
# {'Age (Years)': 22, 'Distance Commuted to Work (Km)': 19.12, 'Employer Company': 'Phillips-Nixon', 'Dependants': 2, 'First Name': 'Lindsey', 'Bank IBAN': 'GB04OJXZ36629513168495', 'Last Name': 'Perry', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 89661, 'Sex': 'Female', 'Address': {'Street': 'Studio 39L Fisher junction', 'City': 'Lukeport', 'Postcode': 'B5 6HB'}, 'Vehicle': {'Make': 'Toyota', 'Model': 'Civic', 'Year': 2018, 'Type': 'Coupe, Convertible'}, 'Credit Card': {'Start Date': '01/18', 'Expiry Date': '06/27', 'Number': 4664684197667, 'CVV': 643}}
# {'Age (Years)': 57, 'Distance Commuted to Work (Km)': 18.78, 'Employer Company': 'Collins Group', 'Dependants': 2, 'First Name': 'Grace', 'Bank IBAN': 'GB51LSRK16179476021409', 'Last Name': 'Davies', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 87098, 'Sex': 'Female', 'Address': {'Street': 'Studio 88 Collins fords', 'City': 'Lake Howard', 'Postcode': 'W4 0AA'}, 'Vehicle': {'Make': 'Chrysler', 'Model': 'Sierra 3500 HD Crew Cab', 'Year': 2006, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '04/19', 'Expiry Date': '10/25', 'Number': 4570776433251267822, 'CVV': 132}}
# {'Age (Years)': 60, 'Distance Commuted to Work (Km)': 7.57, 'Employer Company': 'Webb Group', 'Dependants': 3, 'First Name': 'Albert', 'Bank IBAN': 'GB61YUTS59935062271665', 'Last Name': 'Steele', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 24329, 'Sex': 'Male', 'Address': {'Street': '82 Paige bridge', 'City': 'Port Elaine', 'Postcode': 'B5 3BF'}, 'Vehicle': {'Make': 'Ford', 'Model': 'Prelude', 'Year': 2012, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '02/14', 'Expiry Date': '07/26', 'Number': 2720472635543578, 'CVV': 899}}
# {'Age (Years)': 72, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 1, 'First Name': 'Geoffrey', 'Bank IBAN': 'GB54ZXCM95740026097623', 'Last Name': 'Ward', 'Marital Status': 'single', 'Yearly Pension (GBP)': 21838, 'Retired': True, 'Yearly Salary (GBP)': 97406, 'Sex': 'Male', 'Address': {'Street': '9 Randall center', 'City': 'Donaldmouth', 'Postcode': 'S5 3GT'}, 'Vehicle': {'Make': 'Lincoln', 'Model': 'Silverado 3500 HD Regular Cab', 'Year': 2015, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '03/14', 'Expiry Date': '08/24', 'Number': 377179551619635, 'CVV': '0434'}}
# {'Age (Years)': 86, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 3, 'First Name': 'Adam', 'Bank IBAN': 'GB45RNEO63895090850522', 'Last Name': 'Walsh', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 10651, 'Retired': True, 'Yearly Salary (GBP)': 26452, 'Sex': 'Male', 'Address': {'Street': '57 Edward burg', 'City': 'Shanefurt', 'Postcode': 'FK4B 4HU'}, 'Vehicle': {'Make': 'Subaru', 'Model': 'Commander', 'Year': 1995, 'Type': 'Sedan, Hatchback'}, 'Credit Card': {'Start Date': '01/15', 'Expiry Date': '12/25', 'Number': 379156423792855, 'CVV': 150}}
# {'Age (Years)': 63, 'Distance Commuted to Work (Km)': 5.58, 'Employer Company': 'Graham, Watts and Hall', 'Dependants': 2, 'First Name': 'Peter', 'Bank IBAN': 'GB30EGRJ34862965423758', 'Last Name': 'Burton', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 17245, 'Sex': 'Male', 'Address': {'Street': 'Studio 38 James throughway', 'City': 'Leighton', 'Postcode': 'M8E 7HJ'}, 'Vehicle': {'Make': 'Dodge', 'Model': 'Sorento', 'Year': 2016, 'Type': 'Sedan, Coupe, Hatchback'}, 'Credit Card': {'Start Date': '11/12', 'Expiry Date': '07/22', 'Number': 4058253691525, 'CVV': 458}}
# {'Age (Years)': 33, 'Distance Commuted to Work (Km)': 11.51, 'Employer Company': 'Jones Ltd', 'Dependants': 2, 'First Name': 'Christopher', 'Bank IBAN': 'GB30EKXF93283283335493', 'Last Name': 'Jackson', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 41981, 'Sex': 'Male', 'Address': {'Street': 'Flat 05 Hope prairie', 'City': 'Lake Grace', 'Postcode': 'NG0R 7SG'}, 'Vehicle': {'Make': 'Cadillac', 'Model': 'V90', 'Year': 1996, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '09/13', 'Expiry Date': '05/26', 'Number': 3599564749322901, 'CVV': 927}}
# {'Age (Years)': 46, 'Distance Commuted to Work (Km)': 17.08, 'Employer Company': 'Bailey-George', 'Dependants': 2, 'First Name': 'Gavin', 'Bank IBAN': 'GB05MUJX37298335273577', 'Last Name': 'Holland', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 75117, 'Sex': 'Male', 'Address': {'Street': '83 Jemma estates', 'City': 'Patelchester', 'Postcode': 'KA1N 5UP'}, 'Vehicle': {'Make': 'Ford', 'Model': '3000GT', 'Year': 2003, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '03/18', 'Expiry Date': '05/29', 'Number': '060416002073', 'CVV': '061'}}
# {'Age (Years)': 88, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 2, 'First Name': 'Jeremy', 'Bank IBAN': 'GB68DNZL38729225311976', 'Last Name': 'Richardson', 'Marital Status': 'single', 'Yearly Pension (GBP)': 36202, 'Retired': True, 'Yearly Salary (GBP)': 92899, 'Sex': 'Male', 'Address': {'Street': 'Studio 7 Hill inlet', 'City': 'Barnesfurt', 'Postcode': 'M5 6LA'}, 'Vehicle': {'Make': 'Ford', 'Model': 'ES', 'Year': 1998, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '11/18', 'Expiry Date': '06/19', 'Number': 3567560652090244, 'CVV': 734}}
# {'Age (Years)': 75, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 2, 'First Name': 'Declan', 'Bank IBAN': 'GB35RZFZ68276656752362', 'Last Name': 'Smith', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 19073, 'Retired': True, 'Yearly Salary (GBP)': 59872, 'Sex': 'Male', 'Address': {'Street': 'Studio 05p Gardner fords', 'City': 'North Bradley', 'Postcode': 'BB25 7EP'}, 'Vehicle': {'Make': 'Cadillac', 'Model': 'Rodeo', 'Year': 2013, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '09/19', 'Expiry Date': '02/22', 'Number': 348303225893469, 'CVV': 915}}
# {'Age (Years)': 66, 'Distance Commuted to Work (Km)': 14.39, 'Employer Company': 'Patel-Singh', 'Dependants': 4, 'First Name': 'Christian', 'Bank IBAN': 'GB97UEAX89313220430163', 'Last Name': 'Rogers', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 57934, 'Sex': 'Male', 'Address': {'Street': 'Studio 15 Cooper forges', 'City': 'Port Joel', 'Postcode': 'B2 9AL'}, 'Vehicle': {'Make': 'Toyota', 'Model': 'Tiburon', 'Year': 1998, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '08/20', 'Expiry Date': '10/24', 'Number': '060467338848', 'CVV': 552}}
# {'Age (Years)': 42, 'Distance Commuted to Work (Km)': 14.02, 'Employer Company': 'Pritchard PLC', 'Dependants': 4, 'First Name': 'Kenneth', 'Bank IBAN': 'GB98HIIZ00956490663842', 'Last Name': 'Lewis', 'Marital Status': 'divorced', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 55758, 'Sex': 'Male', 'Address': {'Street': 'Flat 76j Carter junctions', 'City': 'Stanleyton', 'Postcode': 'L9B 0AL'}, 'Vehicle': {'Make': 'Isuzu', 'Model': 929, 'Year': 2003, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '09/19', 'Expiry Date': '04/24', 'Number': 3516368077769117, 'CVV': 168}}
# {'Age (Years)': 72, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 2, 'First Name': 'Abbie', 'Bank IBAN': 'GB40VSFG91266868613507', 'Last Name': 'Gill', 'Marital Status': 'single', 'Yearly Pension (GBP)': 8418, 'Retired': True, 'Yearly Salary (GBP)': 62907, 'Sex': 'Female', 'Address': {'Street': 'Studio 2 Carpenter prairie', 'City': 'West Joyce', 'Postcode': 'N9 4NW'}, 'Vehicle': {'Make': 'Cadillac', 'Model': 'Escape', 'Year': 1996, 'Type': 'Sedan, Hatchback'}, 'Credit Card': {'Start Date': '03/19', 'Expiry Date': '04/22', 'Number': 4697766251032997, 'CVV': 673}}
# {'Age (Years)': 42, 'Distance Commuted to Work (Km)': 17.34, 'Employer Company': 'Fletcher LLC', 'Dependants': 1, 'First Name': 'Steven', 'Bank IBAN': 'GB60ABVW08545614890191', 'Last Name': 'Stanley', 'Marital Status': 'widowed', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 76921, 'Sex': 'Male', 'Address': {'Street': 'Flat 59 Joel pass', 'City': 'Murphystad', 'Postcode': 'B4 6PT'}, 'Vehicle': {'Make': 'Chrysler', 'Model': 'Savana 2500 Cargo', 'Year': 2000, 'Type': 'Coupe'}, 'Credit Card': {'Start Date': '09/17', 'Expiry Date': '03/18', 'Number': 4249162695783341795, 'CVV': 177}}
# {'Age (Years)': 32, 'Distance Commuted to Work (Km)': 15.91, 'Employer Company': 'Edwards, Clarke and Palmer', 'Dependants': 5, 'First Name': 'Carly', 'Bank IBAN': 'GB36ZZMR85340990776081', 'Last Name': 'Wright', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 67367, 'Sex': 'Female', 'Address': {'Street': 'Studio 20 Lisa shores', 'City': 'Malcolmstad', 'Postcode': 'SE7B 0WY'}, 'Vehicle': {'Make': 'Nissan', 'Model': 'Excel', 'Year': 2000, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '06/13', 'Expiry Date': '05/27', 'Number': 2700040848589771, 'CVV': 864}}
# {'Age (Years)': 33, 'Distance Commuted to Work (Km)': 11.95, 'Employer Company': 'Williams PLC', 'Dependants': 4, 'First Name': 'Lorraine', 'Bank IBAN': 'GB49DVCP36360318826870', 'Last Name': 'Duncan', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 44279, 'Sex': 'Female', 'Address': {'Street': '487 Gordon village', 'City': 'Hicksstad', 'Postcode': 'E8E 8BN'}, 'Vehicle': {'Make': 'Plymouth', 'Model': 'F150 SuperCrew Cab', 'Year': 2001, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '05/16', 'Expiry Date': '12/24', 'Number': 36118097797433, 'CVV': 308}}
# {'Age (Years)': 54, 'Distance Commuted to Work (Km)': 11.01, 'Employer Company': 'Carter, Ward and Smith', 'Dependants': 2, 'First Name': 'Jasmine', 'Bank IBAN': 'GB54URZU46329075531104', 'Last Name': 'Khan', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 39466, 'Sex': 'Female', 'Address': {'Street': 'Studio 24X Saunders plain', 'City': 'Cartwrightton', 'Postcode': 'HX36 6ZR'}, 'Vehicle': {'Make': 'Toyota', 'Model': 'NV3500 HD Passenger', 'Year': 1994, 'Type': 'Convertible'}, 'Credit Card': {'Start Date': '05/13', 'Expiry Date': '06/20', 'Number': 213136955108829, 'CVV': 386}}
# {'Age (Years)': 48, 'Distance Commuted to Work (Km)': 19.13, 'Employer Company': 'Day-Thomas', 'Dependants': 2, 'First Name': 'Darren', 'Bank IBAN': 'GB94ENEM74278534672022', 'Last Name': 'Davies', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 89697, 'Sex': 'Male', 'Address': {'Street': '010 Eric street', 'City': 'New Reecefurt', 'Postcode': 'SS7A 4EP'}, 'Vehicle': {'Make': 'Mercedes-Benz', 'Model': 'DTS', 'Year': 1992, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '01/17', 'Expiry Date': '01/19', 'Number': 4126501097843, 'CVV': 911}}
# {'Age (Years)': 37, 'Distance Commuted to Work (Km)': 11.99, 'Employer Company': 'Lambert, Parker and Brown', 'Dependants': 2, 'First Name': 'Paula', 'Bank IBAN': 'GB87FHXK16979131324991', 'Last Name': 'Roberts', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 44472, 'Sex': 'Female', 'Address': {'Street': 'Flat 23D Nicola isle', 'City': 'South Garethmouth', 'Postcode': 'RG3 2AG'}, 'Vehicle': {'Make': 'Jeep', 'Model': 'SX4', 'Year': 2013, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '05/19', 'Expiry Date': '09/22', 'Number': 6536049037488506, 'CVV': '077'}}
# {'Age (Years)': 87, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 1, 'First Name': 'Tracey', 'Bank IBAN': 'GB32HKXY65019270186072', 'Last Name': 'Knight', 'Marital Status': 'single', 'Yearly Pension (GBP)': 19833, 'Retired': True, 'Yearly Salary (GBP)': 90989, 'Sex': 'Female', 'Address': {'Street': '8 King roads', 'City': 'Helenmouth', 'Postcode': 'M3 5FE'}, 'Vehicle': {'Make': 'Mitsubishi', 'Model': 'Wrangler', 'Year': 2005, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '07/14', 'Expiry Date': '08/25', 'Number': 3534803293002842, 'CVV': 889}}
# {'Age (Years)': 67, 'Distance Commuted to Work (Km)': 19.27, 'Employer Company': 'Richardson-Watts', 'Dependants': 3, 'First Name': 'Carolyn', 'Bank IBAN': 'GB76HNHE42862201326025', 'Last Name': 'Roberts', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 90740, 'Sex': 'Female', 'Address': {'Street': 'Flat 53 Hollie motorway', 'City': 'East Raymond', 'Postcode': 'JE18 7AJ'}, 'Vehicle': {'Make': 'Cadillac', 'Model': 'Sienna', 'Year': 2002, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '03/12', 'Expiry Date': '04/15', 'Number': 4490098078370237180, 'CVV': 161}}
# {'Age (Years)': 43, 'Distance Commuted to Work (Km)': 17.74, 'Employer Company': 'James, Whitehouse and Mellor', 'Dependants': 2, 'First Name': 'Jill', 'Bank IBAN': 'GB27ZJWQ46159728183894', 'Last Name': 'Bolton', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 79692, 'Sex': 'Female', 'Address': {'Street': '7 Damien islands', 'City': 'Port Gerald', 'Postcode': 'DL1X 6LX'}, 'Vehicle': {'Make': 'Ford', 'Model': 'Capri', 'Year': 2002, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '02/19', 'Expiry Date': '07/23', 'Number': 38691209119520, 'CVV': 627}}
# {'Age (Years)': 29, 'Distance Commuted to Work (Km)': 14.97, 'Employer Company': 'Morley-Murphy', 'Dependants': 5, 'First Name': 'Ashleigh', 'Bank IBAN': 'GB21JLVB79701886585201', 'Last Name': 'Gray', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 61470, 'Sex': 'Female', 'Address': {'Street': 'Flat 40m Zoe prairie', 'City': 'West Alexanderstad', 'Postcode': 'OL3 4ZL'}, 'Vehicle': {'Make': 'GMC', 'Model': 'Elantra', 'Year': 1993, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '07/16', 'Expiry Date': '08/25', 'Number': 30536923107327, 'CVV': 828}}
# {'Age (Years)': 26, 'Distance Commuted to Work (Km)': 13.28, 'Employer Company': 'Baldwin Inc', 'Dependants': 2, 'First Name': 'Adrian', 'Bank IBAN': 'GB67ACGW20850632829786', 'Last Name': 'Saunders', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 51461, 'Sex': 'Male', 'Address': {'Street': 'Flat 50T White mountain', 'City': 'New Dennis', 'Postcode': 'SY7 5DE'}, 'Vehicle': {'Make': 'Buick', 'Model': 'Safari Passenger', 'Year': 1999, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '10/16', 'Expiry Date': '08/28', 'Number': 4571532967094, 'CVV': 456}}
# {'Age (Years)': 63, 'Distance Commuted to Work (Km)': 15.55, 'Employer Company': 'Jackson-Crawford', 'Dependants': 1, 'First Name': 'Beverley', 'Bank IBAN': 'GB54LORL45412135355270', 'Last Name': 'Marsden', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 65036, 'Sex': 'Female', 'Address': {'Street': '8 Thompson trace', 'City': 'Liamside', 'Postcode': 'PA38 9ZB'}, 'Vehicle': {'Make': 'Dodge', 'Model': 'F150 Regular Cab', 'Year': 2019, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '06/16', 'Expiry Date': '01/19', 'Number': 4430760141221, 'CVV': 9897}}
# {'Age (Years)': 90, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 2, 'First Name': 'Peter', 'Bank IBAN': 'GB74IEMW86147848359945', 'Last Name': 'Fox', 'Marital Status': 'single', 'Yearly Pension (GBP)': 22344, 'Retired': True, 'Yearly Salary (GBP)': 66210, 'Sex': 'Male', 'Address': {'Street': 'Flat 05 Sally lock', 'City': 'Port Paul', 'Postcode': 'DA92 4YE'}, 'Vehicle': {'Make': 'Mercedes-Benz', 'Model': 'HHR', 'Year': 2009, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '05/20', 'Expiry Date': '02/28', 'Number': 3537707829547534, 'CVV': 991}}
# {'Age (Years)': 50, 'Distance Commuted to Work (Km)': 18.33, 'Employer Company': 'Johnston PLC', 'Dependants': 2, 'First Name': 'Justin', 'Bank IBAN': 'GB04FHAM30531487708212', 'Last Name': 'Frost', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 83864, 'Sex': 'Male', 'Address': {'Street': '7 Brown keys', 'City': 'Warrenberg', 'Postcode': 'S3K 4HD'}, 'Vehicle': {'Make': 'GMC', 'Model': 'Spectra', 'Year': 1999, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '01/15', 'Expiry Date': '04/27', 'Number': 375453789760657, 'CVV': 596}}
# {'Age (Years)': 73, 'Distance Commuted to Work (Km)': 18.08, 'Employer Company': 'White, Bray and Iqbal', 'Dependants': 2, 'First Name': 'Chelsea', 'Bank IBAN': 'GB97WUTP26823806991952', 'Last Name': 'Byrne', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 82084, 'Sex': 'Female', 'Address': {'Street': '1 James meadow', 'City': 'Gracetown', 'Postcode': 'L1 6GY'}, 'Vehicle': {'Make': 'GMC', 'Model': 'Amigo', 'Year': 1998, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '12/15', 'Expiry Date': '02/29', 'Number': 4054920547752, 'CVV': 635}}
# ...
# {'Age (Years)': 51, 'Distance Commuted to Work (Km)': 17.8, 'Employer Company': 'Williams-Owen', 'Dependants': 3, 'First Name': 'Molly', 'Bank IBAN': 'GB44HFGK01536480769158', 'Last Name': 'Jackson', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 80081, 'Sex': 'Female', 'Address': {'Street': 'Flat 56 King light', 'City': 'North Brianmouth', 'Postcode': 'M0 6BL'}, 'Vehicle': {'Make': 'Ford', 'Model': 'Equinox', 'Year': 2018, 'Type': 'Sedan, Wagon'}, 'Credit Card': {'Start Date': '08/20', 'Expiry Date': '09/29', 'Number': 3596465827103382, 'CVV': 884}}
# {'Age (Years)': 68, 'Distance Commuted to Work (Km)': 17.84, 'Employer Company': 'Marshall Group', 'Dependants': 2, 'First Name': 'Vincent', 'Bank IBAN': 'GB20EBXM99989526790238', 'Last Name': 'Tomlinson', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 80386, 'Sex': 'Male', 'Address': {'Street': '05 Amelia coves', 'City': 'Paigebury', 'Postcode': 'NE9 0TH'}, 'Vehicle': {'Make': 'Lexus', 'Model': 'Transit 150 Van', 'Year': 2006, 'Type': 'Hatchback'}, 'Credit Card': {'Start Date': '02/17', 'Expiry Date': '08/17', 'Number': 2712481340291282, 'CVV': 442}}
# {'Age (Years)': 37, 'Distance Commuted to Work (Km)': 15.48, 'Employer Company': 'Pearson, Collins and Marsh', 'Dependants': 1, 'First Name': 'Peter', 'Bank IBAN': 'GB22LYFJ95732218003692', 'Last Name': 'Sharp', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 64609, 'Sex': 'Male', 'Address': {'Street': '777 Aaron valleys', 'City': 'Johnmouth', 'Postcode': 'B07 5ZZ'}, 'Vehicle': {'Make': 'BMW', 'Model': 'LR3', 'Year': 2010, 'Type': 'Coupe'}, 'Credit Card': {'Start Date': '05/20', 'Expiry Date': '01/26', 'Number': 30525246640890, 'CVV': 8503}}
# {'Age (Years)': 50, 'Distance Commuted to Work (Km)': 16.12, 'Employer Company': 'Davies, Pearce and Williams', 'Dependants': 1, 'First Name': 'Vincent', 'Bank IBAN': 'GB30EGOC73092573029419', 'Last Name': 'Swift', 'Marital Status': 'divorced', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 68728, 'Sex': 'Male', 'Address': {'Street': 'Flat 22 Mandy squares', 'City': 'Shanehaven', 'Postcode': 'SR18 1EZ'}, 'Vehicle': {'Make': 'GMC', 'Model': 'Mercedes-AMG GLC Coupe', 'Year': 2012, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '09/20', 'Expiry Date': '04/22', 'Number': 30458339325577, 'CVV': 799}}
# {'Age (Years)': 26, 'Distance Commuted to Work (Km)': 8.8, 'Employer Company': 'Fisher-Hill', 'Dependants': 2, 'First Name': 'Lydia', 'Bank IBAN': 'GB52OFTT26226743199049', 'Last Name': 'Reed', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 29320, 'Sex': 'Female', 'Address': {'Street': 'Flat 08d Taylor path', 'City': 'Smartside', 'Postcode': 'HU4N 6YX'}, 'Vehicle': {'Make': 'FIAT', 'Model': 'Odyssey', 'Year': 2010, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '09/16', 'Expiry Date': '01/27', 'Number': 4636042339397, 'CVV': 691}}
# {'Age (Years)': 43, 'Distance Commuted to Work (Km)': 16.19, 'Employer Company': 'Morton-Collins', 'Dependants': 2, 'First Name': 'Marc', 'Bank IBAN': 'GB55TNII01672776605843', 'Last Name': 'Payne', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 69182, 'Sex': 'Male', 'Address': {'Street': 'Studio 99 Curtis rest', 'City': 'Port Laurenmouth', 'Postcode': 'BH8P 0UX'}, 'Vehicle': {'Make': 'Land Rover', 'Model': 'Avalon', 'Year': 2005, 'Type': 'Hatchback'}, 'Credit Card': {'Start Date': '12/14', 'Expiry Date': '06/26', 'Number': 3513475804187324, 'CVV': 349}}
# {'Age (Years)': 30, 'Distance Commuted to Work (Km)': 17.11, 'Employer Company': 'Rahman-Parker', 'Dependants': 2, 'First Name': 'Ellie', 'Bank IBAN': 'GB97KQVY80253351403949', 'Last Name': 'Wright', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 75305, 'Sex': 'Female', 'Address': {'Street': '20 Dean lakes', 'City': 'Meganland', 'Postcode': 'N4E 6XQ'}, 'Vehicle': {'Make': 'Chevrolet', 'Model': 'Tracer', 'Year': 2002, 'Type': 'Coupe'}, 'Credit Card': {'Start Date': '12/18', 'Expiry Date': '01/20', 'Number': 4831634003390, 'CVV': 349}}
# {'Age (Years)': 53, 'Distance Commuted to Work (Km)': 12.44, 'Employer Company': 'Jennings LLC', 'Dependants': 2, 'First Name': 'Simon', 'Bank IBAN': 'GB14PIHK07386954050456', 'Last Name': 'Murphy', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 46840, 'Sex': 'Male', 'Address': {'Street': '12 Potter squares', 'City': 'Dominicside', 'Postcode': 'WC5R 4ES'}, 'Vehicle': {'Make': 'Honda', 'Model': 'Silverado 2500 Regular Cab', 'Year': 2017, 'Type': 'Sedan, Hatchback'}, 'Credit Card': {'Start Date': '06/15', 'Expiry Date': '05/18', 'Number': 213106364189587, 'CVV': 677}}
# {'Age (Years)': 38, 'Distance Commuted to Work (Km)': 12.18, 'Employer Company': 'Ball, Hughes and Robinson', 'Dependants': 3, 'First Name': 'Catherine', 'Bank IBAN': 'GB48DASS31162887870344', 'Last Name': 'Lowe', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 45491, 'Sex': 'Female', 'Address': {'Street': 'Studio 6 McCarthy forest', 'City': 'New Damian', 'Postcode': 'IV7X 8SY'}, 'Vehicle': {'Make': 'Dodge', 'Model': 'Thunderbird', 'Year': 1996, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '02/18', 'Expiry Date': '01/28', 'Number': 3578812940643665, 'CVV': 451}}
# {'Age (Years)': 84, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': '', 'First Name': 'Hazel', 'Bank IBAN': 'GB43GWMR08993795489139', 'Last Name': 'Hayward', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 25214, 'Retired': True, 'Yearly Salary (GBP)': 22020, 'Sex': 'Female', 'Address': {'Street': 'Flat 75 Russell orchard', 'City': 'Katiemouth', 'Postcode': 'SL5 9RD'}, 'Vehicle': {'Make': 'Mercedes-Benz', 'Model': 'Durango', 'Year': 1998, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '07/14', 'Expiry Date': '08/14', 'Number': 4081841962314861, 'CVV': 314}}
# {'Age (Years)': 54, 'Distance Commuted to Work (Km)': 12.1, 'Employer Company': 'Marshall LLC', 'Dependants': 4, 'First Name': 'Lorraine', 'Bank IBAN': 'GB19NWSV06173347245700', 'Last Name': 'Mistry', 'Marital Status': 'divorced', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 45051, 'Sex': 'Female', 'Address': {'Street': '34 Mary locks', 'City': 'Tonymouth', 'Postcode': 'L2 1RH'}, 'Vehicle': {'Make': 'Nissan', 'Model': 'RS 7', 'Year': 1997, 'Type': 'Wagon'}, 'Credit Card': {'Start Date': '08/14', 'Expiry Date': '07/28', 'Number': 4715230313056061953, 'CVV': 314}}
# {'Age (Years)': 83, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 2, 'First Name': 'Aaron', 'Bank IBAN': 'GB04ZDRK14974964545353', 'Last Name': 'Mistry', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 16436, 'Retired': True, 'Yearly Salary (GBP)': 66220, 'Sex': 'Male', 'Address': {'Street': '71 Smith stravenue', 'City': 'Lesleytown', 'Postcode': 'MK0 1HD'}, 'Vehicle': {'Make': 'GMC', 'Model': 'Venture Cargo', 'Year': 2018, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '08/20', 'Expiry Date': '11/21', 'Number': 38175563559869, 'CVV': 684}}
# {'Age (Years)': 90, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 1, 'First Name': 'Kieran', 'Bank IBAN': 'GB32QNPA26143392126454', 'Last Name': 'Thomas', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 25776, 'Retired': True, 'Yearly Salary (GBP)': 26654, 'Sex': 'Male', 'Address': {'Street': 'Studio 51 Scott summit', 'City': 'East Shane', 'Postcode': 'N2 8WH'}, 'Vehicle': {'Make': 'Kia', 'Model': '3 Series', 'Year': 2003, 'Type': 'Coupe, Convertible'}, 'Credit Card': {'Start Date': '10/12', 'Expiry Date': '01/18', 'Number': 2711366246819743, 'CVV': 863}}
# {'Age (Years)': 29, 'Distance Commuted to Work (Km)': 18.81, 'Employer Company': "O'Sullivan, Taylor and Cox", 'Dependants': 2, 'First Name': 'Rachel', 'Bank IBAN': 'GB62ONWU62915681538019', 'Last Name': 'Smart', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 87344, 'Sex': 'Female', 'Address': {'Street': '64 Patterson centers', 'City': 'Cliffordburgh', 'Postcode': 'B24 8EJ'}, 'Vehicle': {'Make': 'Volkswagen', 'Model': 'Sprinter 3500 Cargo', 'Year': 1994, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '10/18', 'Expiry Date': '07/29', 'Number': 4839668463521, 'CVV': 133}}
# {'Age (Years)': 76, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 2, 'First Name': 'Trevor', 'Bank IBAN': 'GB27KLPB12136922168928', 'Last Name': 'Goddard', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 28990, 'Retired': True, 'Yearly Salary (GBP)': 48597, 'Sex': 'Male', 'Address': {'Street': 'Studio 6 Leslie keys', 'City': 'Andreastad', 'Postcode': 'KA4X 1QR'}, 'Vehicle': {'Make': 'Scion', 'Model': 'Vibe', 'Year': 2005, 'Type': 'Wagon'}, 'Credit Card': {'Start Date': '10/17', 'Expiry Date': '12/28', 'Number': 675992264696, 'CVV': 909}}
# {'Age (Years)': 33, 'Distance Commuted to Work (Km)': 7.77, 'Employer Company': 'Archer Ltd', 'Dependants': 1, 'First Name': 'Katy', 'Bank IBAN': 'GB78HGUW98653392316629', 'Last Name': 'Knight', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 25115, 'Sex': 'Female', 'Address': {'Street': '133 Jacob spur', 'City': 'East Mathew', 'Postcode': 'M0S 0GJ'}, 'Vehicle': {'Make': 'Suzuki', 'Model': 'Silverado 2500 HD Extended Cab', 'Year': 2012, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '12/15', 'Expiry Date': '07/20', 'Number': 180029638928433, 'CVV': 292}}
# {'Age (Years)': 30, 'Distance Commuted to Work (Km)': 11.68, 'Employer Company': 'Ashton, Tucker and Davies', 'Dependants': 1, 'First Name': 'Bradley', 'Bank IBAN': 'GB44HFCB98336374626479', 'Last Name': 'Thompson', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 42838, 'Sex': 'Male', 'Address': {'Street': 'Studio 58D Hill dam', 'City': 'West Owenview', 'Postcode': 'B48 1FB'}, 'Vehicle': {'Make': 'Freightliner', 'Model': 'Nautilus', 'Year': 2011, 'Type': 'Wagon, Convertible'}, 'Credit Card': {'Start Date': '08/14', 'Expiry Date': '04/32', 'Number': 4547049098636508, 'CVV': 401}}
# {'Age (Years)': 39, 'Distance Commuted to Work (Km)': 8.85, 'Employer Company': 'Roberts, Thompson and Thomas', 'Dependants': 1, 'First Name': 'Antony', 'Bank IBAN': 'GB43NXOW18067474519071', 'Last Name': 'Edwards', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 29557, 'Sex': 'Male', 'Address': {'Street': '54 Josephine point', 'City': 'South William', 'Postcode': 'WN6B 7PF'}, 'Vehicle': {'Make': 'Volkswagen', 'Model': 'Eclipse', 'Year': 1997, 'Type': 'SUV'}, 'Credit Card': {'Start Date': '12/19', 'Expiry Date': '11/23', 'Number': 4616406508082341, 'CVV': 295}}
# {'Age (Years)': 39, 'Distance Commuted to Work (Km)': 19.84, 'Employer Company': 'Kennedy LLC', 'Dependants': 2, 'First Name': 'Simon', 'Bank IBAN': 'GB02UMII22298941128830', 'Last Name': 'Pollard', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 95080, 'Sex': 'Male', 'Address': {'Street': 'Studio 19 Booth freeway', 'City': 'West Louisehaven', 'Postcode': 'GU8 4EX'}, 'Vehicle': {'Make': 'Jaguar', 'Model': 'Mystique', 'Year': 2017, 'Type': 'Coupe'}, 'Credit Card': {'Start Date': '08/14', 'Expiry Date': '12/19', 'Number': 4886378845716753, 'CVV': 578}}
# {'Age (Years)': 69, 'Distance Commuted to Work (Km)': 15.49, 'Employer Company': 'Jones, Simmons and Wyatt', 'Dependants': 2, 'First Name': 'Amelia', 'Bank IBAN': 'GB09KABU79666494796792', 'Last Name': 'Cooper', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 64712, 'Sex': 'Female', 'Address': {'Street': '66 Hutchinson run', 'City': 'New Joanneton', 'Postcode': 'B3G 0RL'}, 'Vehicle': {'Make': 'Mercedes-Benz', 'Model': 'M6', 'Year': 2014, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '10/15', 'Expiry Date': '12/24', 'Number': 4152915649386239, 'CVV': '018'}}
# {'Age (Years)': 90, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 3, 'First Name': 'Joel', 'Bank IBAN': 'GB60TSJL96687346319661', 'Last Name': 'Sykes', 'Marital Status': 'single', 'Yearly Pension (GBP)': 15650, 'Retired': True, 'Yearly Salary (GBP)': 49928, 'Sex': 'Male', 'Address': {'Street': 'Flat 35h Kathleen extensions', 'City': 'Lake Owenmouth', 'Postcode': 'G3 8PL'}, 'Vehicle': {'Make': 'Nissan', 'Model': 'Prizm', 'Year': 1994, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '06/15', 'Expiry Date': '07/26', 'Number': 213131632975005, 'CVV': 911}}
# {'Age (Years)': 48, 'Distance Commuted to Work (Km)': 18.44, 'Employer Company': 'Phillips-Pope', 'Dependants': 2, 'First Name': 'Leonard', 'Bank IBAN': 'GB45UVZH05043505193524', 'Last Name': 'Clark', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 84645, 'Sex': 'Male', 'Address': {'Street': 'Studio 6 Heather prairie', 'City': 'North Amelia', 'Postcode': 'E9 0HB'}, 'Vehicle': {'Make': 'Saturn', 'Model': 'Convertible', 'Year': 2015, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '04/19', 'Expiry Date': '08/26', 'Number': 3563802099155576, 'CVV': 908}}
# {'Age (Years)': 22, 'Distance Commuted to Work (Km)': 19.61, 'Employer Company': 'Hughes LLC', 'Dependants': 2, 'First Name': 'Jemma', 'Bank IBAN': 'GB88EGZV32518465934497', 'Last Name': 'Jones', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 93314, 'Sex': 'Female', 'Address': {'Street': 'Flat 3 Davies run', 'City': 'Greenshire', 'Postcode': 'E7 4UJ'}, 'Vehicle': {'Make': 'Toyota', 'Model': 'Yukon', 'Year': 2015, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '05/12', 'Expiry Date': '07/28', 'Number': 3591311819315276, 'CVV': 675}}
# {'Age (Years)': 38, 'Distance Commuted to Work (Km)': 6.66, 'Employer Company': 'Bailey Group', 'Dependants': 1, 'First Name': 'Nicola', 'Bank IBAN': 'GB81SVHK17718594367943', 'Last Name': 'Walker', 'Marital Status': 'single', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 20940, 'Sex': 'Female', 'Address': {'Street': 'Flat 7 Barber motorway', 'City': 'Burrowsshire', 'Postcode': 'L62 8TA'}, 'Vehicle': {'Make': 'Ford', 'Model': 'S6', 'Year': 2020, 'Type': 'Sedan'}, 'Credit Card': {'Start Date': '01/13', 'Expiry Date': '05/29', 'Number': 3584931475767707, 'CVV': 679}}
# {'Age (Years)': 45, 'Distance Commuted to Work (Km)': 18.13, 'Employer Company': 'Foster-Price', 'Dependants': 3, 'First Name': 'Paul', 'Bank IBAN': 'GB14LLBD59118062249339', 'Last Name': 'Thomson', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 82412, 'Sex': 'Male', 'Address': {'Street': '00 Tony forks', 'City': 'Abbiebury', 'Postcode': 'NP4 1JL'}, 'Vehicle': {'Make': 'Scion', 'Model': 'Ram 1500 Quad Cab', 'Year': 2015, 'Type': 'Pickup'}, 'Credit Card': {'Start Date': '04/19', 'Expiry Date': '05/23', 'Number': 4090311300716168, 'CVV': 775}}
# {'Age (Years)': 80, 'Distance Commuted to Work (Km)': 0, 'Employer Company': 'N/A', 'Dependants': 1, 'First Name': 'Sheila', 'Bank IBAN': 'GB45ORXV49380519147072', 'Last Name': 'Russell', 'Marital Status': 'single', 'Yearly Pension (GBP)': 22869, 'Retired': True, 'Yearly Salary (GBP)': 25788, 'Sex': 'Female', 'Address': {'Street': 'Flat 9 Mohamed route', 'City': 'West Glen', 'Postcode': 'LL3M 4WS'}, 'Vehicle': {'Make': 'Geo', 'Model': 'S7', 'Year': 1993, 'Type': 'Van/Minivan'}, 'Credit Card': {'Start Date': '12/14', 'Expiry Date': '01/16', 'Number': 180020306382110, 'CVV': 903}}

# %% [markdown]
# ***
# ### <u>**Task 3**:</u>
# a. Scan through the customer collection and check for errors ("" or " ") in the dependants field.<br>
# b. Replace empty dependants with zeros.<br>
# c. Print a list where all such errors take place (I have called it "problematic indices" here)
# ***

# %%
# Initialise a list to contain the problematic indices
problematic_indices = []

# Replace problematic values with zeros and append the indices to the list
for cust_key, ochubas_customer in enumerate(ochubas_customers):
    if ochubas_customer['Dependants'] == '' or ochubas_customer['Dependants'] == ' ':
        ochubas_customer['Dependants'] = 0
        problematic_indices.append(cust_key)

# %%
# Print the indices of customers with erroneous values for dependants

print('\033[1m' + 'Problematic rows for dependants: ' + '\033[0m') #The first escape sequence turns on bold format, and the second turns it off.
print(problematic_indices)

print(f'\n\nTotal number of problematic dependant rows is: \033[1m{len(problematic_indices)}\033[0m')
# Out:
# Problematic rows for dependants:
# [21, 109, 179, 205, 270, 272, 274, 358, 460, 468, 579, 636, 679, 725, 822, 865, 917, 931, 983]
#
#
# Total number of problematic dependant rows is: 19

# %% [markdown]
# ***
# ### <u>**Task 4**:</u>
# After correcting the errors in the dependants column of the Write all records to a <b>processed.json</b> file in the JSON data format. This is a list of dictionaries, where each index of the list is a dictionary representing a singular customer.
#
# ***

# %%
# Write updated customers to a processed.json file using a context manager

with open("processed.json", "w") as processed_customers_file:
    json.dump(ochubas_customers, processed_customers_file)

# %% [markdown]
# ***
# ### <u>**Task 5**:</u>
# a. Extract retired customers and employed customers into separate json files. <br>
# b. Retired customers should be in the <b>retired.json</b> file. <br>
# c. Employed customers should be in the <b>employed.json</b> file.
# ***

# %%
# Create separate lists for retired and employed customers
retired_customers = [customer for customer in ochubas_customers if customer['Retired'] == True]
employed_customers = [customer for customer in ochubas_customers if customer['Employer Company'] != 'N/A']

# Write retired list to the retired.json file
with open('retired.json', 'w') as retired:
    json.dump(retired_customers, retired)

# Write employed list to the employed.json file
with open('employed.json', 'w') as employed:
    json.dump(employed_customers, employed)


print(f'Total number of retired customers is: \033[1m{len(retired_customers)}\033[0m')
print(f'Total number of employed customers is: \033[1m{len(employed_customers)}\033[0m')
# Out:
# Total number of retired customers is: 246
# Total number of employed customers is: 754

# %% [markdown]
# ***
# ### <u>**Task 6**:</u>
# <b>Extract customers that have more than 10 years between start and end dates.</b> <br>
# a. Create a function to check each row from the csv data and flag the row if credit card date difference is above 10 years. <br>
# b. Write all flagged customers to a separate file called <b>remove_ccard.json</b>, in the JSON data format
#  file.
# ***

# %%
# Function to check the difference between two dates

def check_date_difference(start_date, end_date):
    """
    This function takes two dates (MM/YY) and calculates the difference between them

    Parameters:
    - start_date (string): A date string containing MM/YY
    - end_date (string): A date string containing MM/YY
    
    Returns:
    float: the resultant difference between the two dates
    """
    start_month, start_year = start_date.split('/') # Split the start_date string into start month and start year
    end_month, end_year = end_date.split('/') # Split the end_date string into end month and end year
    year_diff = int(end_year) - int(start_year) # Get the difference between start and end years
    month_diff = int(end_month) - int(start_month) # get the difference between the start and end months
    
    date_diff = float(r"{:.2f}".format(year_diff + month_diff/12)) # Divide the month difference by 12 to get the year equivalent. This expresses the month differnece as a fraction of a year.
    return date_diff

# %%
# Function to check whether a customer should be removed based on the 
# difference between start date and expiry date of credit card

def should_remove_customer(customer):
    """
    This function takes a customer and flags it if the date difference between 
    the credit card dates is higher than 10 years

    Parameters:
    - customer (dictionary): A customer dictionary containing key-value pairs of customer data
    
    Returns:
    bool: a boolean value indicating whether a customer should be removed
    """
    ccard_start_date = customer['Credit Card']['Start Date'] # Get the credit card start date from the customer
    ccard_expiry_date = customer['Credit Card']['Expiry Date'] # Get the credit card expiry date from the customer
    
    date_diff = check_date_difference(ccard_start_date, ccard_expiry_date) # Use the check_date_difference function to get the differnce in dates 
    
    if date_diff > 10: #If the date difference is greater than 10, customer flag should be set to true, else set to false.
        return True
    return False

# %%
# Create a list of customers that should be removed based on their credit card date difference

remove_ccard = [customer for customer in ochubas_customers if should_remove_customer(customer)]

# Write removed customers to a json file

with open('remove_ccard.json', 'w') as remove_ccard_file:
    json.dump(remove_ccard, remove_ccard_file)

print(f'Total number of customers with credit card date difference over 10 years is: \033[1m{len(remove_ccard)}\033[0m')
# Out:
# Total number of customers with credit card date difference over 10 years is: 252

# %% [markdown]
# ***
# ### <u>**Task 7**:</u>
# Add a new data attribute called “Salary-Commute” to each customer from the <b>processed.json</b> file.<br>
# <b>a.</b> The Salary-Commute is the salary that a customer earns per kilometre (km) of their commute.<br>
#     If a person travels 1 or fewer commute Km, then their Salary-Commute would be just their salary.<br>
# <b>b.</b> Sort customers by Salary-Commute in ascending order.<br>
# <b>c.</b> Export sorted customers to a <b>commute.json</b> file.
# ***

# %%
# Read processed customers from json file into a list

processed_customers = []
with open('processed.json') as processed_file:
    processed_customers = json.load(processed_file)
    
print(processed_customers[1]) # Inspect random customer before appending the 'Salary-Commute' property
# Out:
# {'Age (Years)': 46, 'Distance Commuted to Work (Km)': 13.72, 'Employer Company': 'Begum-Williams', 'Dependants': 1, 'First Name': 'Jonathan', 'Bank IBAN': 'GB37UMCO54540228728019', 'Last Name': 'Thomas', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 54016, 'Sex': 'Male', 'Address': {'Street': '00 Wheeler wells', 'City': 'Chapmanton', 'Postcode': 'L2 7BT'}, 'Vehicle': {'Make': 'Nissan', 'Model': 'ATS', 'Year': 1996, 'Type': 'Coupe'}, 'Credit Card': {'Start Date': '08/12', 'Expiry Date': '11/26', 'Number': 4529436854129855, 'CVV': 583}}

# %%
# Exercise 7a

# Function to add 'Salary-Commute' property to a customer
def add_salary_commute_property(customer):
    commute_distance = customer['Distance Commuted to Work (Km)']
    salary = customer['Yearly Salary (GBP)']
    if commute_distance <= 1:
        customer['Salary-Commute'] = salary
    else:
        customer['Salary-Commute'] = round(salary/commute_distance, 2)

# Use the function above to add salary commute to all the customers that we read from the 'processed.json' file
for customer in processed_customers:
    add_salary_commute_property(customer)

print(processed_customers[1]) # Inspect same customer after appending the 'Salary-Commute' property
# Out:
# {'Age (Years)': 46, 'Distance Commuted to Work (Km)': 13.72, 'Employer Company': 'Begum-Williams', 'Dependants': 1, 'First Name': 'Jonathan', 'Bank IBAN': 'GB37UMCO54540228728019', 'Last Name': 'Thomas', 'Marital Status': 'married or civil partner', 'Yearly Pension (GBP)': 0, 'Retired': False, 'Yearly Salary (GBP)': 54016, 'Sex': 'Male', 'Address': {'Street': '00 Wheeler wells', 'City': 'Chapmanton', 'Postcode': 'L2 7BT'}, 'Vehicle': {'Make': 'Nissan', 'Model': 'ATS', 'Year': 1996, 'Type': 'Coupe'}, 'Credit Card': {'Start Date': '08/12', 'Expiry Date': '11/26', 'Number': 4529436854129855, 'CVV': 583}, 'Salary-Commute': 3937.03}

# %%
# Using a lambda expression, sort the customers based on the Salary-Commute property.
processed_customers.sort(key=lambda customer: customer['Salary-Commute'])

# Write the updated customers to a new file called 'commute.json'
with open("commute.json", "w") as commute_file:
    json.dump(processed_customers, commute_file)

# %% [markdown]
# ## **Part Two: Data Visualisation**

# %%
# Import needed libraries for data visualisation

import pandas as pd
import seaborn as sns

# %%
user_data = pd.read_csv('acw_user_data.csv') #Read in the data from the csv file into a pandas Dataframe.
user_data # Inspect the content of the pandas Dataframe
# Out:
#                 Address Street    Address City Address Postcode  Age (Years)  \
# 0                70 Lydia isle      Lake Conor          S71 7XZ           89
# 1             00 Wheeler wells      Chapmanton           L2 7BT           46
# 2         Studio 33K Joel walk  Randallborough         ME3N 1GH           22
# 3    Studio 46S Bethany lights      East Reece          E10 9RJ           56
# 4       Flat 3 Christine views    Fletcherstad          WS2 9SN           57
# ..                         ...             ...              ...          ...
# 995   Studio 6 Heather prairie    North Amelia           E9 0HB           48
# 996          Flat 3 Davies run      Greenshire           E7 4UJ           22
# 997     Flat 7 Barber motorway    Burrowsshire          L62 8TA           38
# 998              00 Tony forks       Abbiebury          NP4 1JL           45
# 999       Flat 9 Mohamed route       West Glen         LL3M 4WS           80
#
#      Distance Commuted to Work (Km)          Employer Company  \
# 0                              0.00                       NaN
# 1                             13.72            Begum-Williams
# 2                             16.02               Hill-Wright
# 3                             19.35                 Green LLC
# 4                              5.94  Hill, Evans and Harrison
# ..                              ...                       ...
# 995                           18.44             Phillips-Pope
# 996                           19.61                Hughes LLC
# 997                            6.66              Bailey Group
# 998                           18.13              Foster-Price
# 999                            0.00                       NaN
#
#     Credit Card Start Date Credit Card Expiry Date   Credit Card Number  \
# 0                    08/18                   11/27         676373692463
# 1                    08/12                   11/26     4529436854129855
# 2                    11/19                   07/27  4091726363083888495
# 3                    10/17                   04/18  4671332769487632633
# 4                    04/19                   11/27     2245094149128526
# ..                     ...                     ...                  ...
# 995                  04/19                   08/26     3563802099155576
# 996                  05/12                   07/28     3591311819315276
# 997                  01/13                   05/29     3584931475767707
# 998                  04/19                   05/23     4090311300716168
# 999                  12/14                   01/16      180020306382110
#
#      Credit Card CVV  ...  Last Name            Marital Status  \
# 0                875  ...     Wilson  married or civil partner
# 1                583  ...     Thomas  married or civil partner
# 2                422  ...      Jones  married or civil partner
# 3                669  ...       Shaw  married or civil partner
# 4                659  ...    O'Brien  married or civil partner
# ..               ...  ...        ...                       ...
# 995              908  ...      Clark  married or civil partner
# 996              675  ...      Jones  married or civil partner
# 997              679  ...     Walker                    single
# 998              775  ...    Thomson  married or civil partner
# 999              903  ...    Russell                    single
#
#     Yearly Pension (GBP) Retired Yearly Salary (GBP)     Sex  Vehicle Make  \
# 0                   7257    True               72838    Male       Hyundai
# 1                      0   False               54016    Male        Nissan
# 2                      0   False               68049    Male           GMC
# 3                      0   False               91337    Male         Scion
# 4                      0   False               18446  Female         Buick
# ..                   ...     ...                 ...     ...           ...
# 995                    0   False               84645    Male        Saturn
# 996                    0   False               93314  Female        Toyota
# 997                    0   False               20940  Female          Ford
# 998                    0   False               82412    Male         Scion
# 999                22869    True               25788  Female           Geo
#
#           Vehicle Model Vehicle Year        Vehicle Type
# 0            Bonneville         2009              Pickup
# 1                   ATS         1996               Coupe
# 2               Achieva         2015  Convertible, Coupe
# 3    F150 SuperCrew Cab         1994              Pickup
# 4               Outback         2020                 SUV
# ..                  ...          ...                 ...
# 995         Convertible         2015         Van/Minivan
# 996               Yukon         2015         Van/Minivan
# 997                  S6         2020               Sedan
# 998   Ram 1500 Quad Cab         2015              Pickup
# 999                  S7         1993         Van/Minivan
#
# [1000 rows x 23 columns]

# %% [markdown]
# ***
# ### <u>**Task 1**:</u>
# Obtain the Data Series for Salary, and Age, and calculate the following:<br>
# a. Mean Salary<br>
# b. Median Age
# ***

# %%
salaries_ds = user_data['Yearly Salary (GBP)'] # Extract the salary column of the dataframe as a data series
ages_ds = user_data['Age (Years)'] # Extract the age column of the dataframe as a data series

# %%
mean_salary = salaries_ds.mean() # Task 1a - Obtain the mean salary
median_age = ages_ds.median() # Task 1b - Obtain the median age

# Print values
print("The mean salary is: \033[1m", mean_salary, "\033[0m")
print("The median age is: \033[1m", median_age, "\033[0m")
# Out:
# The mean salary is:  57814.078
# The median age is:  54.0

# %% [markdown]
# ***
# ### <u>**Task 2**:</u>
# Perform univariate plots of the following data attributes:<br>
# a. Age, calculating how many bins would be required for a bin_width of 5. <br>
# b. Dependents, fixing data errors with seaborn itself.<br>
# c. Age (of default bins), conditioned on Marital Status.
# ***

# %%
# Task 2a
# Calculate the number of bins required for a bin width of 5

bin_width = 5
number_of_bins = round((max(ages_ds) - min(ages_ds))/bin_width)
print("Number of bins for a bin width of 5 is: \033[1m", number_of_bins, "\033[0m" )
# Out:
# Number of bins for a bin width of 5 is:  15

# %%
# Univariate plot of customer ages with bin-width of 5;
age_plot_handle = sns.displot(ages_ds, binwidth = 5, color = '#66CDAA', kde=True).set(title = 'Frequency Distribution of Customer Ages') # We assign a handle to it so that we can save the figure later on
age_plot_handle.axes[0, 0].set_ylabel("Frequency"); # Set ylabel for the chart

# %%
# Task 2b
# Univariate plot of customer dependants, fixing data errors with seaborn itself;

corrected_dependants = user_data['Dependants'].fillna(0) # Fix error in dependant column by filling it with zeros
zero_dependants = [dep for dep in corrected_dependants if dep == 0] # Get the customers with zero dependants

print(f'Total number of customers with zero dependants is: \033[1m{len(zero_dependants)}\033[0m')
# Out:
# Total number of customers with zero dependants is: 19

# %%
# Exercise 2b
# Univariate plot of customer dependants

dependant_plot_handle = sns.countplot(data = user_data, x = corrected_dependants, color = '#6a5acd')
dependant_plot_handle.set_title('Frequency Distribution of Customer Dependants') # Set chart title
dependant_plot_handle.set_xlabel("Number of Dependants"); # Override the default xlabel for the chart
dependant_plot_handle.set_ylabel("Frequency"); # Override the default ylabel for the chart

# %%
# Task 2c
# Univariate plot of customer ages with default bins conditioned on marital status

colors=["#08a4a7", "#ffbe98", "#f4141c", "#b6dad2"] #Choose preferred colors for various categories of the conditioned attribute
age_plot_cond_handle = sns.displot(data = user_data, x = ages_ds, hue='Marital Status', palette=colors, multiple = 'stack')\
                          .set(title = 'Customer Age Distribution Conditioned on Marital Status') # We set multiple to 'stack' to avoid overlapping colors

# %% [markdown]
# ***
# ### <u>**Task 3**:</u>
# Perform multivariate plots of the following data attributes:<br>
# a. Commuted distance against salary <br>
# b. Age against Salary <br>
# c. Age against Salary conditioned by Dependants
# ***

# %%
# Exercise 3a
# Multivariate plot of commuted distance against salary

# Using scatter plot
dist_salary_scatter_handle = sns.scatterplot(data = user_data, x = 'Distance Commuted to Work (Km)', y = 'Yearly Salary (GBP)', color = '#6C6377')
dist_salary_scatter_handle.get_figure().suptitle("Commute Distance vs. Yearly Salary");

# %%
# We plot the same chart using an alternate chart type (lmplot) for comparison
dist_vs_salary_lmplot_handle = sns.lmplot(data = user_data, x = 'Distance Commuted to Work (Km)', y = 'Yearly Salary (GBP)')\
                            .set(title = "Commute Distance vs. Yearly Salary")

# %%
# Multivariate plot of age against salary using scatterplot
age_salary_scatter_handle = sns.scatterplot(data = user_data, x = 'Age (Years)', y = 'Yearly Salary (GBP)', color = '#000080')
age_salary_scatter_handle.get_figure().suptitle("Chart of Age vs. Salary");

# %%
# Exercise 3b
# Multivariate plot of age against salary using regplot which adds a regression line

age_salary_reg_handle = sns.regplot(data = user_data, x = 'Age (Years)', y = 'Yearly Salary (GBP)', color = '#828C7E')
age_salary_reg_handle.get_figure().suptitle("Chart of Age vs. Salary");

# %%
# Exercise 3b
# Multivariate plot of age against salary conditioned on dependants

colors=["#e3f0de", "#bedcb2", "#a3cd92", "#82a474", "#516649", "#10140e"] #Choose preferred colors for various categories of the conditioned attribute
age_salary_cond_handle = sns.scatterplot(data = user_data, x = 'Age (Years)', y = 'Yearly Salary (GBP)', hue= corrected_dependants, palette = colors)

# %% [markdown]
# ***
# ### <u>**Task 4**:</u>
# Save all charts
# ***

# %%
charts_to_save = {}
charts_to_save[age_plot_handle] = 'age_plot.png'
charts_to_save[dependant_plot_handle] = 'dependant_plot.png'
charts_to_save[age_plot_cond_handle] = 'age_plot_cond.png'
charts_to_save[dist_salary_scatter_handle] = 'dist_salary_scatter.png'
charts_to_save[dist_vs_salary_lmplot_handle] = 'dist_salary_lm.png'
charts_to_save[age_salary_scatter_handle] = 'age_salary_scatter.png'
charts_to_save[age_salary_reg_handle] = 'age_salary_reg.png'
charts_to_save[age_salary_cond_handle] = 'age_salary_cond.png'


for chart_handle, chart_name in charts_to_save.items():
    chart_handle.figure.savefig(chart_name)
    print(f'\033[1m{chart_name}\033[0m has been saved to the directory.')
# Out:
# age_plot.png has been saved to the directory.
# dependant_plot.png has been saved to the directory.
# age_plot_cond.png has been saved to the directory.
# dist_salary_scatter.png has been saved to the directory.
# dist_salary_lm.png has been saved to the directory.
# age_salary_scatter.png has been saved to the directory.
# age_salary_reg.png has been saved to the directory.
# age_salary_cond.png has been saved to the directory.
